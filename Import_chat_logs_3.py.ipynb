# %% [markdown]
# This notebook transform Q&A pairs into co-occurrency tables, counting the frequency of each non-stopword term in question and answer

# %%
import psycopg2
conn = psycopg2.connect(user="postgres", password="mysecretpassword", host="localhost")
# distinct connection to perform insertions while iterating over the SELECT results
insertion_conn = psycopg2.connect(user="postgres", password="mysecretpassword", host="localhost")
# should be UTF-8
print('connection encoding, used as default:', conn.encoding)
# Out:
# connection encoding, used as default: UTF8

# %%
cur = conn.cursor()
cur.execute("CREATE TABLE IF NOT EXISTS words_tmp (word_q VARCHAR(30), word_a VARCHAR(30), counter INTEGER);")
cur.execute("CREATE TABLE IF NOT EXISTS bigrams_tmp (token1 VARCHAR(30), token2 VARCHAR(30), counter INTEGER);")
cur.execute("TRUNCATE TABLE words_tmp;")
cur.execute("TRUNCATE TABLE bigrams_tmp;")
conn.commit()

# %% [markdown]
# Use a named cursor `window_read_cursor` to read the conversation by channel sort by date, so that consecutive messages in the same channel come together.
#
# The named cursor is necessary to iterate over an important amount of data, which would not easily fit into memory

# %%
import time
import random
from datetime import datetime

named_cur = conn.cursor('window_read_cursor')
insertion_cur = insertion_conn.cursor()


# table schema:
# chat_messages (message TEXT, message_time TIMESTAMP, username TEXT, channel TEXT)
print("about to run query")
named_cur.execute("SELECT question, answer FROM qa_pair")


start_time = time.time()

print("iterating over query results")
total = 0
to_store = {}
to_store_bigrams = {}

stopwords_it = set(["a","ad","agl","agli","ai","al","alcuna","alcuni","alcuno","all","alla","alle","allo","allora","altri","altro","anche","ancora","aver","avere","averlo","avesse","avessero","avessi","avessimo","aveste","avesti","avete","aveva","avevamo","avevano","avevate","avevi","avevo","avrai","avranno","avrebbe","avrebbero","avrei","avremmo","avremo","avreste","avresti","avrete","avrà","avrò","avuta","avute","avuti","avuto",
                    "basta","è","il","le", "che", "un","una","uno","perché","mi","di","ma","per","in","non","e","si","sto","la","lo","gli","con","nel","già","da","i","sono","come","se","io","ho","più","però","ti","su","hai","fa","per","tra","fra","me","ha","ci","del","poi","o","cosa","cose","mai","fare"])

# do not filter out stopwords for now, keep the raw data
stopwords_it = set()

external_token = '**EXTERNAL**'

for record in named_cur:
    tokens_q = set(record[0].lower().split())
    tokens_a = set(record[1].lower().split())
    for q in tokens_q:
        if q in stopwords_it or len(q) > 30:
            continue
        for a in tokens_a:
            if a in stopwords_it or len(a) > 30:
                continue
            if (q,a) not in to_store:
                to_store[(q,a)] = 0 
            to_store[(q,a)] += 1

            
    padded = [external_token] + record[0].lower().split() + [external_token]
    for pos in range(len(padded) -1 ):
        bg = (padded[pos][:30], padded[pos + 1][:30])
        if bg not in to_store_bigrams:
            to_store_bigrams[bg] = 0
        to_store_bigrams[bg] += 1
        
    padded = [external_token] + record[1].lower().split() + [external_token]
    for pos in range(len(padded) -1 ):
        bg = (padded[pos][:30], padded[pos + 1][:30])
        if bg not in to_store_bigrams:
            to_store_bigrams[bg] = 0
        to_store_bigrams[bg] += 1
    total += 1
    if len(to_store) + len(to_store_bigrams) > 150000:
        print(f'{datetime.now().isoformat()} - insertion after {total} pairs')
        for pair,count in to_store.items():
            insertion_cur.execute("INSERT INTO words_tmp (word_q, word_a, counter) VALUES (%s, %s, %s)", (pair[0], pair[1], count))
        for pair,count in to_store_bigrams.items():
            insertion_cur.execute("INSERT INTO bigrams_tmp (token1, token2, counter) VALUES (%s, %s, %s)", (pair[0], pair[1], count))
   
        to_store = {}
        to_store_bigrams = {}

        insertion_conn.commit()
    
insertion_conn.commit()
insertion_cur.close()


elapsed_time = round(time.time() - start_time)
print(f'{total} pairs examined in {elapsed_time} seconds')
# Out:
# about to run query
# iterating over query results
# insertion after 1827 pairs
# insertion after 3388 pairs
# insertion after 4967 pairs
# insertion after 6747 pairs
# insertion after 8306 pairs
# insertion after 11464 pairs
# insertion after 13218 pairs
# insertion after 14521 pairs
# insertion after 15976 pairs
# insertion after 17631 pairs
# insertion after 19472 pairs
# insertion after 21075 pairs
# insertion after 22962 pairs
# insertion after 24461 pairs
# insertion after 26041 pairs
# insertion after 27709 pairs
# insertion after 29192 pairs
# insertion after 30656 pairs
# insertion after 32372 pairs
# insertion after 34279 pairs
# insertion after 35897 pairs
# insertion after 37093 pairs
# insertion after 38601 pairs
# insertion after 39943 pairs
# insertion after 41397 pairs
# insertion after 42747 pairs
# insertion after 44421 pairs
# insertion after 45926 pairs
# insertion after 47655 pairs
# insertion after 50387 pairs
# insertion after 52038 pairs
# insertion after 53566 pairs
# insertion after 55244 pairs
# insertion after 56873 pairs
# insertion after 59754 pairs
# insertion after 61658 pairs
# insertion after 63974 pairs
# insertion after 64763 pairs
# insertion after 66432 pairs
# insertion after 69097 pairs
# insertion after 70865 pairs
# insertion after 72665 pairs
# insertion after 74302 pairs
# insertion after 76244 pairs
# insertion after 77986 pairs
# insertion after 80282 pairs
# insertion after 83545 pairs
# insertion after 86713 pairs
# insertion after 90683 pairs
# insertion after 94753 pairs
# insertion after 99487 pairs
# insertion after 102913 pairs
# insertion after 111126 pairs
# insertion after 116583 pairs
# insertion after 118373 pairs
# insertion after 121625 pairs
# insertion after 125026 pairs
# insertion after 129221 pairs
# insertion after 133429 pairs
# insertion after 137914 pairs
# insertion after 142941 pairs
# insertion after 146788 pairs
# insertion after 151082 pairs
# insertion after 153074 pairs
# insertion after 154985 pairs
# insertion after 157042 pairs
# insertion after 158589 pairs
# insertion after 160503 pairs
# insertion after 162467 pairs
# insertion after 164412 pairs
# insertion after 166403 pairs
# insertion after 168342 pairs
# insertion after 170384 pairs
# insertion after 172519 pairs
# insertion after 174287 pairs
# insertion after 176282 pairs
# insertion after 178357 pairs
# insertion after 180289 pairs
# insertion after 182263 pairs
# insertion after 184741 pairs
# insertion after 188302 pairs
# insertion after 192633 pairs
# insertion after 196730 pairs
# insertion after 200731 pairs
# insertion after 205265 pairs
# insertion after 209768 pairs
# insertion after 214431 pairs
# insertion after 218761 pairs
# insertion after 221789 pairs
# insertion after 225345 pairs
# insertion after 229013 pairs
# insertion after 233730 pairs
# insertion after 236802 pairs
# insertion after 239843 pairs
# insertion after 243920 pairs
# insertion after 247072 pairs
# insertion after 249940 pairs
# insertion after 252793 pairs
# insertion after 257028 pairs
# insertion after 260841 pairs
# insertion after 264634 pairs
# insertion after 268293 pairs
# insertion after 271748 pairs
# insertion after 276734 pairs
# insertion after 281301 pairs
# insertion after 286546 pairs
# insertion after 291973 pairs
# insertion after 295783 pairs
# insertion after 299398 pairs
# insertion after 302985 pairs
# insertion after 306120 pairs
# insertion after 309441 pairs
# insertion after 313497 pairs
# insertion after 317416 pairs
# insertion after 320832 pairs
# insertion after 325139 pairs
# insertion after 328565 pairs
# insertion after 332959 pairs
# insertion after 336608 pairs
# insertion after 340165 pairs
# insertion after 343342 pairs
# insertion after 346978 pairs
# insertion after 350973 pairs
# insertion after 354345 pairs
# insertion after 358055 pairs
# insertion after 361713 pairs
# insertion after 365519 pairs
# insertion after 369679 pairs
# insertion after 374319 pairs
# insertion after 377403 pairs
# insertion after 381318 pairs
# insertion after 382397 pairs
# insertion after 383652 pairs
# insertion after 385048 pairs
# insertion after 386605 pairs
# insertion after 388058 pairs
# insertion after 389733 pairs
# insertion after 391060 pairs
# insertion after 392572 pairs
# insertion after 394221 pairs
# insertion after 395862 pairs
# insertion after 397549 pairs
# insertion after 398928 pairs
# insertion after 400218 pairs
# insertion after 402006 pairs
# insertion after 403574 pairs
# insertion after 404882 pairs
# insertion after 406506 pairs
# insertion after 407600 pairs
# insertion after 408868 pairs
# insertion after 410109 pairs
# insertion after 411439 pairs
# insertion after 412848 pairs
# insertion after 415042 pairs
# insertion after 418746 pairs
# insertion after 422603 pairs
# insertion after 425674 pairs
# insertion after 429548 pairs
# insertion after 433445 pairs
# insertion after 435501 pairs
# insertion after 438111 pairs
# insertion after 440356 pairs
# insertion after 442578 pairs
# insertion after 444951 pairs
# insertion after 447701 pairs
# insertion after 450886 pairs
# insertion after 453229 pairs
# insertion after 455623 pairs
# insertion after 458548 pairs
# insertion after 461063 pairs
# insertion after 463270 pairs
# insertion after 465988 pairs
# insertion after 469067 pairs
# insertion after 471423 pairs
# insertion after 473599 pairs
# insertion after 475484 pairs
# insertion after 477422 pairs
# insertion after 479801 pairs
# insertion after 482179 pairs
# insertion after 484175 pairs
# insertion after 486046 pairs
# insertion after 488572 pairs
# insertion after 490991 pairs
# insertion after 493250 pairs
# insertion after 495290 pairs
# insertion after 497626 pairs
# insertion after 500148 pairs
# insertion after 502575 pairs
# insertion after 504621 pairs
# insertion after 507213 pairs
# insertion after 509474 pairs
# insertion after 511304 pairs
# insertion after 512926 pairs
# insertion after 515276 pairs
# insertion after 517967 pairs
# insertion after 520055 pairs
# insertion after 522156 pairs
# insertion after 524268 pairs
# insertion after 526419 pairs
# insertion after 528552 pairs
# insertion after 530884 pairs
# insertion after 533003 pairs
# insertion after 535339 pairs
# insertion after 537502 pairs
# insertion after 540122 pairs
# insertion after 542814 pairs
# insertion after 545088 pairs
# insertion after 547751 pairs
# insertion after 550478 pairs
# insertion after 553132 pairs
# insertion after 555361 pairs
# insertion after 557688 pairs
# insertion after 559868 pairs
# insertion after 561896 pairs
# insertion after 564190 pairs
# insertion after 566644 pairs
# insertion after 568789 pairs
# insertion after 570590 pairs
# insertion after 573106 pairs
# insertion after 575451 pairs
# insertion after 577862 pairs
# insertion after 580531 pairs
# insertion after 582735 pairs
# insertion after 584775 pairs
# insertion after 586920 pairs
# insertion after 589125 pairs
# insertion after 591831 pairs
# insertion after 594173 pairs
# insertion after 596372 pairs
# insertion after 598481 pairs
# insertion after 600579 pairs
# insertion after 602478 pairs
# insertion after 604776 pairs
# insertion after 607340 pairs
# insertion after 609540 pairs
# insertion after 611916 pairs
# insertion after 614433 pairs
# insertion after 616701 pairs
# insertion after 620800 pairs
# insertion after 624291 pairs
# insertion after 627055 pairs
# insertion after 630698 pairs
# insertion after 634069 pairs
# insertion after 637634 pairs
# insertion after 641478 pairs
# insertion after 645140 pairs
# insertion after 648654 pairs
# insertion after 651975 pairs
# insertion after 656656 pairs
# insertion after 660521 pairs
# insertion after 664109 pairs
# insertion after 668221 pairs
# insertion after 671904 pairs
# insertion after 675501 pairs
# insertion after 679965 pairs
# insertion after 682830 pairs
# insertion after 687709 pairs
# insertion after 690877 pairs
# insertion after 694790 pairs
# insertion after 698797 pairs
# insertion after 702457 pairs
# insertion after 706326 pairs
# insertion after 709684 pairs
# insertion after 712013 pairs
# insertion after 714046 pairs
# insertion after 716421 pairs
# insertion after 718806 pairs
# insertion after 720805 pairs
# insertion after 722989 pairs
# insertion after 725225 pairs
# insertion after 727682 pairs
# insertion after 729812 pairs
# insertion after 731828 pairs
# insertion after 734070 pairs
# insertion after 736146 pairs
# insertion after 737991 pairs
# insertion after 740179 pairs
# insertion after 742175 pairs
# insertion after 744430 pairs
# insertion after 746333 pairs
# insertion after 748637 pairs
# insertion after 750766 pairs
# insertion after 753224 pairs
# insertion after 755980 pairs
# insertion after 757919 pairs
# insertion after 760094 pairs
# insertion after 762401 pairs
# insertion after 765361 pairs
# insertion after 767896 pairs
# insertion after 769886 pairs
# insertion after 772620 pairs
# insertion after 774801 pairs
# insertion after 777314 pairs
# insertion after 779947 pairs
# insertion after 782850 pairs
# insertion after 785798 pairs
# insertion after 788357 pairs
# insertion after 790442 pairs
# insertion after 793197 pairs
# insertion after 796216 pairs
# insertion after 798658 pairs
# insertion after 801246 pairs
# insertion after 803685 pairs
# insertion after 806086 pairs
# insertion after 808823 pairs
# insertion after 811576 pairs
# insertion after 814254 pairs
# insertion after 816746 pairs
# insertion after 819210 pairs
# insertion after 821604 pairs
# insertion after 824319 pairs
# insertion after 826533 pairs
# insertion after 828701 pairs
# insertion after 831209 pairs
# insertion after 833600 pairs
# insertion after 836485 pairs
# insertion after 839130 pairs
# insertion after 841759 pairs
# insertion after 844365 pairs
# insertion after 846716 pairs
# insertion after 848913 pairs
# insertion after 851232 pairs
# insertion after 853569 pairs
# insertion after 855999 pairs
# insertion after 858112 pairs
# insertion after 860269 pairs
# insertion after 862607 pairs
# insertion after 864606 pairs
# insertion after 867036 pairs
# insertion after 869454 pairs
# insertion after 871533 pairs
# insertion after 873298 pairs
# 874231 pairs examined in 82657 seconds

# %%
start_time = time.time()
cur = conn.cursor()
cur.execute("CREATE TABLE words AS SELECT word_q, word_a, SUM(counter) as counter FROM words_tmp GROUP BY word_q, word_a;")
conn.commit()
cur.execute("CREATE TABLE bigrams AS SELECT token1, token2, SUM(counter) as counter FROM bigrams_tmp GROUP BY token1, token2;")
conn.commit()
cur.execute("DROP TABLE bigrams_tmp;")
cur.execute("DROP TABLE words_tmp;")
conn.commit()

elapsed_time = round(time.time() - start_time)
print(f'tables created, tmp tables dropped in {elapsed_time} seconds')

start_time = time.time()

cur.execute("CREATE INDEX question_w ON words(word_q);")
conn.commit()
cur.execute("CREATE INDEX answer_w ON words(word_a);")
conn.commit()

cur.execute("create table word_counts as select sum(counter) as total, token1 as token from bigrams group by token1;")
conn.commit()

cur.execute("""create table relevances as (select word_a, word_q, counter/(wc_a.total + wc_q.total) as relevance
FROM words
JOIN word_counts wc_a ON wc_a.token = word_a
JOIN word_counts wc_q ON wc_q.token = word_q);""")
conn.commit()


elapsed_time = round(time.time() - start_time)
print(f'aggregate table created in {elapsed_time} seconds')
# Out:
# tables created, tmp tables dropped in 1219 seconds
# aggregate table created in 272 seconds
