# %% [markdown]
# This notebook transform conversation logs into a set of Q&A pairs. A pair is a list of consecutive messages from two different users. The Q (Question) is made of N consecutive message from an user X, the A (Answer) part is made of M consecutive message from an user Y.
# Note that Q is not necessarily a Question, but just a prompt for a reply which makes sense with the A part outside the context, so a chatbot can be trained solely on the Q&A pairs.

# %%
import psycopg2
conn = psycopg2.connect(user="postgres", password="mysecretpassword", host="localhost")
# distinct connection to perform insertions while iterating over the SELECT results
insertion_conn = psycopg2.connect(user="postgres", password="mysecretpassword", host="localhost")
# should be UTF-8
print('connection encoding, used as default:', conn.encoding)
# Out:
# connection encoding, used as default: UTF8

# %%
cur = conn.cursor()
cur.execute("CREATE TABLE IF NOT EXISTS qa_pair (question TEXT, answer TEXT, context TEXT);")
# cur.execute("TRUNCATE TABLE qa_pair;")
cur.close()
conn.commit()

# %% [markdown]
# Use a named cursor `window_read_cursor` to read the conversation by channel sort by date, so that consecutive messages in the same channel come together.
#
# The named cursor is necessary to iterate over an important amount of data, which would not easily fit into memory

# %%
from collections import deque
from itertools import takewhile, islice
import time
import random

named_cur = conn.cursor('window_read_cursor')
insertion_cur = insertion_conn.cursor()


# table schema:
# chat_messages (message TEXT, message_time TIMESTAMP, username TEXT, channel TEXT)
print("about to run query")
named_cur.execute("SELECT message, message_time, username, channel FROM chat_messages ORDER BY channel ASC, message_time ASC")


start_time = time.time()

window = deque()
window_size = 6
# keep track of the latest channel to detect when the conversation has changed
latest_channel = ''
print("iterating over query results")
total = 0
for record in named_cur:
    
    if len(window) > window_size:
        window.popleft()
    if record[3] != latest_channel:
        window.clear()
        latest_channel = record[3]
    window.append(record)
    # now the window is ready, can we extract a Q&A pair ?
    # do we have more than one utterance? At least one as (Q)uestion/prompt, another as (A)nswer and a third to know A wasn't multi-message
    if len(window) < 3:
        continue
    # first, check that we are not in the middle of an utterance made of consecutive messages from the same user
    if window[-1][2] == window[-2][2]:
        continue
    
    A_user = window[-2][2]
    window_list = list(reversed(window))
    
    # now we know there's an A, check there's a Q
    
    if not any(map(lambda r: r[2] != A_user, window_list[2:])):
        continue
    # extract the consecutive messages to form Q and A
    answer = list(takewhile(lambda r: r[2] == A_user, window_list[1:]))
    # take the last user writing a message in the window before A
    Q_user = window_list[len(answer) + 1][2]
    prompt = list(takewhile(lambda r: r[2] == Q_user, window_list[len(answer) + 1:]))
    if False:
        print('\n\nprompt:')
        for r in prompt:
            print(r[2], ':', r[0])
        print('answer:')
        for r in answer:
            print(r[2], ':', r[0])
        if random.randint(1,1000) == 4:
            break
    total += 1
    q_text = ""
    a_text = ""
    for r in reversed(prompt):
        q_text += '\n' + r[0]
    if len(q_text) < 10 or len(q_text) > 1000:
        continue
    for r in reversed(answer):
        a_text += '\n' + r[0]
    if len(a_text) > 1000 or len(a_text) < 2:
        continue
    context = r[3] + " " + str(r[1])
    insertion_cur.execute("INSERT INTO qa_pair (question, answer, context) VALUES (%s, %s, %s)", (q_text, a_text, context))
    if total % 2000 == 0:
        print(f'extracted {total} QA pairs, committing...')
        insertion_conn.commit()
    
conn.commit()
insertion_cur.close()


elapsed_time = round(time.time() - start_time)
print(f'{total} pairs inserted in {elapsed_time} seconds')
# Out:
# about to run query
# iterating over query results
# extracted 2000 QA pairs, committing...
# extracted 4000 QA pairs, committing...
# extracted 6000 QA pairs, committing...
# extracted 8000 QA pairs, committing...
# extracted 10000 QA pairs, committing...
# extracted 12000 QA pairs, committing...
# extracted 14000 QA pairs, committing...
# extracted 16000 QA pairs, committing...
# extracted 18000 QA pairs, committing...
# extracted 20000 QA pairs, committing...
# extracted 22000 QA pairs, committing...
# extracted 24000 QA pairs, committing...
# extracted 26000 QA pairs, committing...
# extracted 28000 QA pairs, committing...
# extracted 30000 QA pairs, committing...
# extracted 32000 QA pairs, committing...
# extracted 34000 QA pairs, committing...
# extracted 36000 QA pairs, committing...
# extracted 38000 QA pairs, committing...
# extracted 40000 QA pairs, committing...
# extracted 42000 QA pairs, committing...
# extracted 44000 QA pairs, committing...
# extracted 46000 QA pairs, committing...
# extracted 50000 QA pairs, committing...
# extracted 52000 QA pairs, committing...
# extracted 54000 QA pairs, committing...
# extracted 56000 QA pairs, committing...
# extracted 58000 QA pairs, committing...
# extracted 60000 QA pairs, committing...
# extracted 62000 QA pairs, committing...
# extracted 64000 QA pairs, committing...
# extracted 66000 QA pairs, committing...
# extracted 68000 QA pairs, committing...
# extracted 70000 QA pairs, committing...
# extracted 72000 QA pairs, committing...
# extracted 74000 QA pairs, committing...
# extracted 76000 QA pairs, committing...
# extracted 82000 QA pairs, committing...
# extracted 84000 QA pairs, committing...
# extracted 88000 QA pairs, committing...
# extracted 90000 QA pairs, committing...
# extracted 94000 QA pairs, committing...
# extracted 98000 QA pairs, committing...
# extracted 102000 QA pairs, committing...
# extracted 108000 QA pairs, committing...
# extracted 110000 QA pairs, committing...
# extracted 112000 QA pairs, committing...
# extracted 114000 QA pairs, committing...
# extracted 116000 QA pairs, committing...
# extracted 120000 QA pairs, committing...
# extracted 124000 QA pairs, committing...
# extracted 126000 QA pairs, committing...
# extracted 130000 QA pairs, committing...
# extracted 134000 QA pairs, committing...
# extracted 136000 QA pairs, committing...
# extracted 140000 QA pairs, committing...
# extracted 142000 QA pairs, committing...
# extracted 144000 QA pairs, committing...
# extracted 146000 QA pairs, committing...
# extracted 148000 QA pairs, committing...
# extracted 150000 QA pairs, committing...
# extracted 154000 QA pairs, committing...
# extracted 156000 QA pairs, committing...
# extracted 162000 QA pairs, committing...
# extracted 168000 QA pairs, committing...
# extracted 170000 QA pairs, committing...
# extracted 174000 QA pairs, committing...
# extracted 176000 QA pairs, committing...
# extracted 178000 QA pairs, committing...
# extracted 180000 QA pairs, committing...
# extracted 182000 QA pairs, committing...
# extracted 184000 QA pairs, committing...
# extracted 186000 QA pairs, committing...
# extracted 188000 QA pairs, committing...
# extracted 192000 QA pairs, committing...
# extracted 194000 QA pairs, committing...
# extracted 196000 QA pairs, committing...
# extracted 198000 QA pairs, committing...
# extracted 200000 QA pairs, committing...
# extracted 202000 QA pairs, committing...
# extracted 204000 QA pairs, committing...
# extracted 206000 QA pairs, committing...
# extracted 208000 QA pairs, committing...
# extracted 212000 QA pairs, committing...
# extracted 214000 QA pairs, committing...
# extracted 220000 QA pairs, committing...
# extracted 226000 QA pairs, committing...
# extracted 228000 QA pairs, committing...
# extracted 230000 QA pairs, committing...
# extracted 232000 QA pairs, committing...
# extracted 234000 QA pairs, committing...
# extracted 240000 QA pairs, committing...
# extracted 242000 QA pairs, committing...
# extracted 246000 QA pairs, committing...
# extracted 248000 QA pairs, committing...
# extracted 250000 QA pairs, committing...
# extracted 252000 QA pairs, committing...
# extracted 254000 QA pairs, committing...
# extracted 256000 QA pairs, committing...
# extracted 262000 QA pairs, committing...
# extracted 264000 QA pairs, committing...
# extracted 266000 QA pairs, committing...
# extracted 270000 QA pairs, committing...
# extracted 272000 QA pairs, committing...
# extracted 276000 QA pairs, committing...
# extracted 280000 QA pairs, committing...
# extracted 282000 QA pairs, committing...
# extracted 288000 QA pairs, committing...
# extracted 290000 QA pairs, committing...
# extracted 292000 QA pairs, committing...
# extracted 294000 QA pairs, committing...
# extracted 296000 QA pairs, committing...
# extracted 298000 QA pairs, committing...
# extracted 300000 QA pairs, committing...
# extracted 302000 QA pairs, committing...
# extracted 306000 QA pairs, committing...
# extracted 308000 QA pairs, committing...
# extracted 314000 QA pairs, committing...
# extracted 316000 QA pairs, committing...
# extracted 318000 QA pairs, committing...
# extracted 322000 QA pairs, committing...
# extracted 326000 QA pairs, committing...
# extracted 330000 QA pairs, committing...
# extracted 332000 QA pairs, committing...
# extracted 334000 QA pairs, committing...
# extracted 336000 QA pairs, committing...
# extracted 338000 QA pairs, committing...
# extracted 340000 QA pairs, committing...
# extracted 342000 QA pairs, committing...
# extracted 344000 QA pairs, committing...
# extracted 348000 QA pairs, committing...
# extracted 352000 QA pairs, committing...
# extracted 354000 QA pairs, committing...
# extracted 356000 QA pairs, committing...
# extracted 360000 QA pairs, committing...
# extracted 362000 QA pairs, committing...
# extracted 366000 QA pairs, committing...
# extracted 368000 QA pairs, committing...
# extracted 370000 QA pairs, committing...
# extracted 372000 QA pairs, committing...
# extracted 374000 QA pairs, committing...
# extracted 376000 QA pairs, committing...
# extracted 378000 QA pairs, committing...
# extracted 382000 QA pairs, committing...
# extracted 384000 QA pairs, committing...
# extracted 386000 QA pairs, committing...
# extracted 388000 QA pairs, committing...
# extracted 392000 QA pairs, committing...
# extracted 396000 QA pairs, committing...
# extracted 398000 QA pairs, committing...
# extracted 400000 QA pairs, committing...
# extracted 402000 QA pairs, committing...
# extracted 404000 QA pairs, committing...
# extracted 406000 QA pairs, committing...
# extracted 408000 QA pairs, committing...
# extracted 412000 QA pairs, committing...
# extracted 416000 QA pairs, committing...
# extracted 418000 QA pairs, committing...
# extracted 420000 QA pairs, committing...
# extracted 422000 QA pairs, committing...
# extracted 426000 QA pairs, committing...
# extracted 428000 QA pairs, committing...
# extracted 430000 QA pairs, committing...
# extracted 432000 QA pairs, committing...
# extracted 434000 QA pairs, committing...
# extracted 436000 QA pairs, committing...
# extracted 440000 QA pairs, committing...
# extracted 442000 QA pairs, committing...
# extracted 452000 QA pairs, committing...
# extracted 454000 QA pairs, committing...
# extracted 456000 QA pairs, committing...
# extracted 458000 QA pairs, committing...
# extracted 460000 QA pairs, committing...
# extracted 464000 QA pairs, committing...
# extracted 466000 QA pairs, committing...
# extracted 468000 QA pairs, committing...
# extracted 470000 QA pairs, committing...
# extracted 472000 QA pairs, committing...
# extracted 474000 QA pairs, committing...
# extracted 478000 QA pairs, committing...
# extracted 480000 QA pairs, committing...
# extracted 484000 QA pairs, committing...
# extracted 488000 QA pairs, committing...
# extracted 494000 QA pairs, committing...
# extracted 496000 QA pairs, committing...
# extracted 498000 QA pairs, committing...
# extracted 500000 QA pairs, committing...
# extracted 504000 QA pairs, committing...
# extracted 506000 QA pairs, committing...
# extracted 508000 QA pairs, committing...
# extracted 510000 QA pairs, committing...
# extracted 512000 QA pairs, committing...
# extracted 516000 QA pairs, committing...
# extracted 518000 QA pairs, committing...
# extracted 520000 QA pairs, committing...
# extracted 522000 QA pairs, committing...
# extracted 524000 QA pairs, committing...
# extracted 526000 QA pairs, committing...
# extracted 528000 QA pairs, committing...
# extracted 532000 QA pairs, committing...
# extracted 534000 QA pairs, committing...
# extracted 536000 QA pairs, committing...
# extracted 538000 QA pairs, committing...
# extracted 540000 QA pairs, committing...
# extracted 542000 QA pairs, committing...
# extracted 544000 QA pairs, committing...
# extracted 546000 QA pairs, committing...
# extracted 548000 QA pairs, committing...
# extracted 550000 QA pairs, committing...
# extracted 556000 QA pairs, committing...
# extracted 558000 QA pairs, committing...
# extracted 560000 QA pairs, committing...
# extracted 562000 QA pairs, committing...
# extracted 564000 QA pairs, committing...
# extracted 566000 QA pairs, committing...
# extracted 568000 QA pairs, committing...
# extracted 570000 QA pairs, committing...
# extracted 572000 QA pairs, committing...
# extracted 574000 QA pairs, committing...
# extracted 576000 QA pairs, committing...
# extracted 578000 QA pairs, committing...
# extracted 580000 QA pairs, committing...
# extracted 584000 QA pairs, committing...
# extracted 586000 QA pairs, committing...
# extracted 588000 QA pairs, committing...
# extracted 590000 QA pairs, committing...
# extracted 592000 QA pairs, committing...
# extracted 594000 QA pairs, committing...
# extracted 596000 QA pairs, committing...
# extracted 598000 QA pairs, committing...
# extracted 600000 QA pairs, committing...
# extracted 602000 QA pairs, committing...
# extracted 604000 QA pairs, committing...
# extracted 606000 QA pairs, committing...
# extracted 608000 QA pairs, committing...
# extracted 610000 QA pairs, committing...
# extracted 612000 QA pairs, committing...
# extracted 614000 QA pairs, committing...
# extracted 618000 QA pairs, committing...
# extracted 622000 QA pairs, committing...
# extracted 624000 QA pairs, committing...
# extracted 626000 QA pairs, committing...
# extracted 628000 QA pairs, committing...
# extracted 630000 QA pairs, committing...
# extracted 632000 QA pairs, committing...
# extracted 634000 QA pairs, committing...
# extracted 638000 QA pairs, committing...
# extracted 640000 QA pairs, committing...
# extracted 642000 QA pairs, committing...
# extracted 644000 QA pairs, committing...
# extracted 646000 QA pairs, committing...
# extracted 648000 QA pairs, committing...
# extracted 652000 QA pairs, committing...
# extracted 654000 QA pairs, committing...
# extracted 656000 QA pairs, committing...
# extracted 658000 QA pairs, committing...
# extracted 660000 QA pairs, committing...
# extracted 662000 QA pairs, committing...
# extracted 664000 QA pairs, committing...
# extracted 666000 QA pairs, committing...
# extracted 668000 QA pairs, committing...
# extracted 670000 QA pairs, committing...
# extracted 672000 QA pairs, committing...
# extracted 674000 QA pairs, committing...
# extracted 676000 QA pairs, committing...
# extracted 678000 QA pairs, committing...
# extracted 680000 QA pairs, committing...
# extracted 682000 QA pairs, committing...
# extracted 684000 QA pairs, committing...
# extracted 686000 QA pairs, committing...
# extracted 688000 QA pairs, committing...
# extracted 690000 QA pairs, committing...
# extracted 692000 QA pairs, committing...
# extracted 696000 QA pairs, committing...
# extracted 698000 QA pairs, committing...
# extracted 700000 QA pairs, committing...
# extracted 702000 QA pairs, committing...
# extracted 704000 QA pairs, committing...
# extracted 706000 QA pairs, committing...
# extracted 712000 QA pairs, committing...
# extracted 714000 QA pairs, committing...
# extracted 716000 QA pairs, committing...
# extracted 718000 QA pairs, committing...
# extracted 720000 QA pairs, committing...
# extracted 722000 QA pairs, committing...
# extracted 724000 QA pairs, committing...
# extracted 726000 QA pairs, committing...
# extracted 728000 QA pairs, committing...
# extracted 730000 QA pairs, committing...
# extracted 734000 QA pairs, committing...
# extracted 736000 QA pairs, committing...
# extracted 738000 QA pairs, committing...
# extracted 740000 QA pairs, committing...
# extracted 742000 QA pairs, committing...
# extracted 746000 QA pairs, committing...
# extracted 748000 QA pairs, committing...
# extracted 750000 QA pairs, committing...
# extracted 754000 QA pairs, committing...
# extracted 756000 QA pairs, committing...
# extracted 758000 QA pairs, committing...
# extracted 762000 QA pairs, committing...
# extracted 766000 QA pairs, committing...
# extracted 768000 QA pairs, committing...
# extracted 770000 QA pairs, committing...
# extracted 772000 QA pairs, committing...
# extracted 774000 QA pairs, committing...
# extracted 776000 QA pairs, committing...
# extracted 778000 QA pairs, committing...
# extracted 780000 QA pairs, committing...
# extracted 782000 QA pairs, committing...
# extracted 784000 QA pairs, committing...
# extracted 790000 QA pairs, committing...
# extracted 792000 QA pairs, committing...
# extracted 794000 QA pairs, committing...
# extracted 796000 QA pairs, committing...
# extracted 798000 QA pairs, committing...
# extracted 800000 QA pairs, committing...
# extracted 808000 QA pairs, committing...
# extracted 812000 QA pairs, committing...
# extracted 816000 QA pairs, committing...
# extracted 818000 QA pairs, committing...
# extracted 820000 QA pairs, committing...
# extracted 824000 QA pairs, committing...
# extracted 826000 QA pairs, committing...
# extracted 834000 QA pairs, committing...
# extracted 838000 QA pairs, committing...
# extracted 842000 QA pairs, committing...
# extracted 844000 QA pairs, committing...
# extracted 846000 QA pairs, committing...
# extracted 852000 QA pairs, committing...
# extracted 854000 QA pairs, committing...
# extracted 856000 QA pairs, committing...
# extracted 858000 QA pairs, committing...
# extracted 860000 QA pairs, committing...
# extracted 864000 QA pairs, committing...
# extracted 866000 QA pairs, committing...
# extracted 868000 QA pairs, committing...
# extracted 870000 QA pairs, committing...
# extracted 872000 QA pairs, committing...
# extracted 874000 QA pairs, committing...
# extracted 876000 QA pairs, committing...
# extracted 878000 QA pairs, committing...
# extracted 880000 QA pairs, committing...
# extracted 884000 QA pairs, committing...
# extracted 888000 QA pairs, committing...
# extracted 892000 QA pairs, committing...
# extracted 894000 QA pairs, committing...
# extracted 896000 QA pairs, committing...
# extracted 898000 QA pairs, committing...
# extracted 900000 QA pairs, committing...
# extracted 902000 QA pairs, committing...
# extracted 904000 QA pairs, committing...
# extracted 906000 QA pairs, committing...
# extracted 908000 QA pairs, committing...
# extracted 910000 QA pairs, committing...
# extracted 912000 QA pairs, committing...
# extracted 914000 QA pairs, committing...
# extracted 918000 QA pairs, committing...
# extracted 924000 QA pairs, committing...
# extracted 926000 QA pairs, committing...
# extracted 928000 QA pairs, committing...
# extracted 930000 QA pairs, committing...
# extracted 932000 QA pairs, committing...
# extracted 934000 QA pairs, committing...
# extracted 936000 QA pairs, committing...
# extracted 938000 QA pairs, committing...
# extracted 940000 QA pairs, committing...
# extracted 948000 QA pairs, committing...
# extracted 950000 QA pairs, committing...
# extracted 952000 QA pairs, committing...
# extracted 954000 QA pairs, committing...
# extracted 956000 QA pairs, committing...
# extracted 958000 QA pairs, committing...
# extracted 960000 QA pairs, committing...
# extracted 962000 QA pairs, committing...
# extracted 964000 QA pairs, committing...
# extracted 966000 QA pairs, committing...
# extracted 968000 QA pairs, committing...
# extracted 972000 QA pairs, committing...
# extracted 976000 QA pairs, committing...
# extracted 978000 QA pairs, committing...
# extracted 980000 QA pairs, committing...
# extracted 984000 QA pairs, committing...
# extracted 986000 QA pairs, committing...
# extracted 988000 QA pairs, committing...
# extracted 990000 QA pairs, committing...
# extracted 992000 QA pairs, committing...
# extracted 994000 QA pairs, committing...
# extracted 996000 QA pairs, committing...
# extracted 998000 QA pairs, committing...
# extracted 1000000 QA pairs, committing...
# extracted 1002000 QA pairs, committing...
# extracted 1004000 QA pairs, committing...
# extracted 1006000 QA pairs, committing...
# extracted 1010000 QA pairs, committing...
# extracted 1012000 QA pairs, committing...
# extracted 1018000 QA pairs, committing...
# extracted 1020000 QA pairs, committing...
# extracted 1022000 QA pairs, committing...
# extracted 1024000 QA pairs, committing...
# extracted 1026000 QA pairs, committing...
# extracted 1028000 QA pairs, committing...
# extracted 1030000 QA pairs, committing...
# extracted 1032000 QA pairs, committing...
# extracted 1034000 QA pairs, committing...
# extracted 1036000 QA pairs, committing...
# extracted 1038000 QA pairs, committing...
# extracted 1040000 QA pairs, committing...
# extracted 1042000 QA pairs, committing...
# extracted 1044000 QA pairs, committing...
# 1044328 pairs inserted in 1334 seconds
